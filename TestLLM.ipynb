# %% [markdown]
# # Test LLM Inference
# This notebook can be used to test inference of LLM models deployed in watsonx.ai. It uses the Watson Machine Learning API. You can find more information about the API [here](https://dataplatform.cloud.ibm.com/docs/content/wsj/analyze-data/fm-python-lib.html?context=wx&audience=wdp)

# %%
# !pip install -r requirements.txt
# Out:
# Collecting load_dotenv==0.1.0 (from -r requirements.txt (line 1))
#   Downloading load_dotenv-0.1.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting ibm_watson_machine_learning==1.0.345 (from -r requirements.txt (line 2))
#   Downloading ibm_watson_machine_learning-1.0.345-py3-none-any.whl.metadata (8.6 kB)
# Collecting ibm-cloud-sdk-core==3.16.7 (from -r requirements.txt (line 3))
#   Downloading ibm-cloud-sdk-core-3.16.7.tar.gz (52 kB)
#      ---------------------------------------- 0.0/52.3 kB ? eta -:--:--
#      ------------------------------- -------- 41.0/52.3 kB 2.0 MB/s eta 0:00:01
#      -------------------------------------- 52.3/52.3 kB 895.0 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting streamlit==1.31.0 (from -r requirements.txt (line 4))
#   Downloading streamlit-1.31.0-py2.py3-none-any.whl.metadata (8.1 kB)
# Collecting python-dotenv==1.0.0 (from -r requirements.txt (line 5))
#   Downloading python_dotenv-1.0.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: requests in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2)) (2.28.2)
# Requirement already satisfied: urllib3 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2)) (1.26.14)
# Requirement already satisfied: pandas<1.6.0,>=0.24.2 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2)) (1.5.3)
# Requirement already satisfied: certifi in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2)) (2022.12.7)
# Collecting lomond (from ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2))
#   Downloading lomond-0.3.3-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting tabulate (from ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2))
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: packaging in c:\users\hardi\appdata\roaming\python\python311\site-packages (from ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2)) (23.0)
# Requirement already satisfied: importlib-metadata in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2)) (6.6.0)
# Collecting ibm-cos-sdk<2.14.0,>=2.12.0 (from ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2))
#   Downloading ibm-cos-sdk-2.13.6.tar.gz (58 kB)
#      ---------------------------------------- 0.0/58.6 kB ? eta -:--:--
#      ---------------------------------------- 58.6/58.6 kB 3.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting requests (from ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2))
#   Downloading requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: python_dateutil<3.0.0,>=2.5.3 in c:\users\hardi\appdata\roaming\python\python311\site-packages (from ibm-cloud-sdk-core==3.16.7->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: PyJWT<3.0.0,>=2.4.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from ibm-cloud-sdk-core==3.16.7->-r requirements.txt (line 3)) (2.7.0)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (1.6.2)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (5.3.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (8.1.3)
# Requirement already satisfied: numpy<2,>=1.19.3 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (1.23.5)
# Requirement already satisfied: pillow<11,>=7.1.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (12.0.0)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.1.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (8.2.2)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (4.12.2)
# Requirement already satisfied: tzlocal<6,>=1.1 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (4.3)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (0.20.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (3.1.31)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (0.8.1b0)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\hardi\appdata\roaming\python\python311\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (6.2)
# Requirement already satisfied: watchdog>=2.1.5 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from streamlit==1.31.0->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: entrypoints in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit==1.31.0->-r requirements.txt (line 4)) (0.4)
# Requirement already satisfied: jinja2 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit==1.31.0->-r requirements.txt (line 4)) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit==1.31.0->-r requirements.txt (line 4)) (4.17.3)
# Requirement already satisfied: toolz in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from altair<6,>=4.0->streamlit==1.31.0->-r requirements.txt (line 4)) (0.12.0)
# Requirement already satisfied: colorama in c:\users\hardi\appdata\roaming\python\python311\site-packages (from click<9,>=7.0->streamlit==1.31.0->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.31.0->-r requirements.txt (line 4)) (4.0.10)
# Collecting ibm-cos-sdk-core==2.13.6 (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2))
#   Downloading ibm-cos-sdk-core-2.13.6.tar.gz (1.1 MB)
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      ---- ----------------------------------- 0.1/1.1 MB 2.4 MB/s eta 0:00:01
#      -------------- ------------------------- 0.4/1.1 MB 4.0 MB/s eta 0:00:01
#      ------------------------- -------------- 0.7/1.1 MB 4.9 MB/s eta 0:00:01
#      --------------------------------- ------ 0.9/1.1 MB 5.8 MB/s eta 0:00:01
#      ---------------------------------------- 1.1/1.1 MB 5.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting ibm-cos-sdk-s3transfer==2.13.6 (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2))
#   Downloading ibm-cos-sdk-s3transfer-2.13.6.tar.gz (139 kB)
#      ---------------------------------------- 0.0/139.5 kB ? eta -:--:--
#      ---------------------------------------- 139.5/139.5 kB ? eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting jmespath<=1.0.1,>=0.10.0 (from ibm-cos-sdk<2.14.0,>=2.12.0->ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2))
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting python_dateutil<3.0.0,>=2.5.3 (from ibm-cloud-sdk-core==3.16.7->-r requirements.txt (line 3))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting requests (from ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2))
#   Downloading requests-2.32.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting urllib3 (from ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2))
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ---------------------------------------- 0.0/50.1 kB ? eta -:--:--
#      ---------------------------------------- 50.1/50.1 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata->ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2)) (3.15.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from pandas<1.6.0,>=0.24.2->ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2)) (2022.7.1)
# Requirement already satisfied: six>=1.5 in c:\users\hardi\appdata\roaming\python\python311\site-packages (from python_dateutil<3.0.0,>=2.5.3->ibm-cloud-sdk-core==3.16.7->-r requirements.txt (line 3)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from requests->ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from requests->ibm_watson_machine_learning==1.0.345->-r requirements.txt (line 2)) (3.4)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from rich<14,>=10.14.0->streamlit==1.31.0->-r requirements.txt (line 4)) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\hardi\appdata\roaming\python\python311\site-packages (from rich<14,>=10.14.0->streamlit==1.31.0->-r requirements.txt (line 4)) (2.14.0)
# Requirement already satisfied: pytz-deprecation-shim in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from tzlocal<6,>=1.1->streamlit==1.31.0->-r requirements.txt (line 4)) (0.1.0.post0)
# Requirement already satisfied: tzdata in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from tzlocal<6,>=1.1->streamlit==1.31.0->-r requirements.txt (line 4)) (2023.3)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\hardi\appdata\roaming\python\python311\site-packages (from validators<1,>=0.2->streamlit==1.31.0->-r requirements.txt (line 4)) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.31.0->-r requirements.txt (line 4)) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit==1.31.0->-r requirements.txt (line 4)) (2.1.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.31.0->-r requirements.txt (line 4)) (23.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.31.0->-r requirements.txt (line 4)) (0.19.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\hardi\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.14.0->streamlit==1.31.0->-r requirements.txt (line 4)) (0.1.2)
# Downloading load_dotenv-0.1.0-py3-none-any.whl (7.2 kB)
# Downloading ibm_watson_machine_learning-1.0.345-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 16.2 MB/s eta 0:00:01
#    --------------------- ------------------ 0.8/1.5 MB 10.6 MB/s eta 0:00:01
#    -------------------------- ------------- 1.0/1.5 MB 8.1 MB/s eta 0:00:01
#    ------------------------------- -------- 1.2/1.5 MB 6.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 1.4/1.5 MB 6.2 MB/s eta 0:00:01
#    ---------------------------------------  1.5/1.5 MB 6.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 5.7 MB/s eta 0:00:00
# Downloading streamlit-1.31.0-py2.py3-none-any.whl (8.4 MB)
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    -- ------------------------------------- 0.4/8.4 MB 8.7 MB/s eta 0:00:01
#    --- ------------------------------------ 0.6/8.4 MB 6.8 MB/s eta 0:00:02
#    --- ------------------------------------ 0.8/8.4 MB 6.1 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.0/8.4 MB 5.8 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.2/8.4 MB 5.1 MB/s eta 0:00:02
#    ------ --------------------------------- 1.4/8.4 MB 4.9 MB/s eta 0:00:02
#    ------- -------------------------------- 1.6/8.4 MB 5.0 MB/s eta 0:00:02
#    -------- ------------------------------- 1.7/8.4 MB 4.8 MB/s eta 0:00:02
#    --------- ------------------------------ 1.9/8.4 MB 4.7 MB/s eta 0:00:02
#    --------- ------------------------------ 1.9/8.4 MB 4.6 MB/s eta 0:00:02
#    --------- ------------------------------ 1.9/8.4 MB 4.6 MB/s eta 0:00:02
#    --------- ------------------------------ 1.9/8.4 MB 4.6 MB/s eta 0:00:02
#    --------- ------------------------------ 1.9/8.4 MB 4.6 MB/s eta 0:00:02
#    --------- ------------------------------ 1.9/8.4 MB 4.6 MB/s eta 0:00:02
#    --------- ------------------------------ 1.9/8.4 MB 4.6 MB/s eta 0:00:02
#    --------- ------------------------------ 1.9/8.4 MB 4.6 MB/s eta 0:00:02
#    --------- ------------------------------ 1.9/8.4 MB 4.6 MB/s eta 0:00:02
#    --------- ------------------------------ 1.9/8.4 MB 4.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 2.2/8.4 MB 2.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 2.2/8.4 MB 2.6 MB/s eta 0:00:03
#    --------------- ------------------------ 3.2/8.4 MB 3.4 MB/s eta 0:00:02
#    --------------- ------------------------ 3.2/8.4 MB 3.4 MB/s eta 0:00:02
#    ------------------ --------------------- 3.8/8.4 MB 3.6 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.4 MB 3.8 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.4 MB 3.8 MB/s eta 0:00:02
#    -------------------- ------------------- 4.2/8.4 MB 3.8 MB/s eta 0:00:02
#    ----------------------- ---------------- 4.9/8.4 MB 4.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.9/8.4 MB 4.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.9/8.4 MB 4.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 4.9/8.4 MB 4.0 MB/s eta 0:00:01
#    ------------------------ --------------- 5.2/8.4 MB 3.7 MB/s eta 0:00:01
#    ------------------------ --------------- 5.2/8.4 MB 3.7 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.1/8.4 MB 4.0 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.2/8.4 MB 3.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.2/8.4 MB 3.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.2/8.4 MB 3.9 MB/s eta 0:00:01
#    ------------------------------ --------- 6.3/8.4 MB 3.7 MB/s eta 0:00:01
#    ------------------------------ --------- 6.5/8.4 MB 3.7 MB/s eta 0:00:01
#    --------------------------------- ------ 7.1/8.4 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.2/8.4 MB 3.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 7.4/8.4 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 7.6/8.4 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------ --- 7.7/8.4 MB 3.9 MB/s eta 0:00:01
#    ------------------------------------- -- 7.9/8.4 MB 3.9 MB/s eta 0:00:01
#    -------------------------------------- - 8.0/8.4 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------  8.3/8.4 MB 3.9 MB/s eta 0:00:01
#    ---------------------------------------- 8.4/8.4 MB 3.9 MB/s eta 0:00:00
# Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ---------------------------------------- 0.0/229.9 kB ? eta -:--:--
#    ---------------------------------------  225.3/229.9 kB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 229.9/229.9 kB 4.7 MB/s eta 0:00:00
# Downloading requests-2.32.2-py3-none-any.whl (63 kB)
#    ---------------------------------------- 0.0/63.9 kB ? eta -:--:--
#    ---------------------------------------- 63.9/63.9 kB 3.4 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ---------------------------------------- 0.0/144.2 kB ? eta -:--:--
#    ---------------------------------------- 144.2/144.2 kB 4.3 MB/s eta 0:00:00
# Downloading lomond-0.3.3-py2.py3-none-any.whl (35 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Building wheels for collected packages: ibm-cloud-sdk-core, ibm-cos-sdk, ibm-cos-sdk-core, ibm-cos-sdk-s3transfer
#   Building wheel for ibm-cloud-sdk-core (pyproject.toml): started
#   Building wheel for ibm-cloud-sdk-core (pyproject.toml): finished with status 'done'
#   Created wheel for ibm-cloud-sdk-core: filename=ibm_cloud_sdk_core-3.16.7-py3-none-any.whl size=85631 sha256=959e802c04be4d7fd9943254c3573bc9f756ed3f13d75a60c0d9a0b6ea9e0409
#   Stored in directory: c:\users\hardi\appdata\local\pip\cache\wheels\9a\6a\a4\51eaeca811e87fc2e669db84e72fd3324d326244c415eece08
#   Building wheel for ibm-cos-sdk (setup.py): started
#   Building wheel for ibm-cos-sdk (setup.py): finished with status 'done'
#   Created wheel for ibm-cos-sdk: filename=ibm_cos_sdk-2.13.6-py3-none-any.whl size=77260 sha256=319bb740be8549f0d4723e6f55a19dfba044d5b5c01deb55dccacf3b86dad8ee
#   Stored in directory: c:\users\hardi\appdata\local\pip\cache\wheels\17\8c\76\f9472a53a2a80da414dd53ca55f08dbfe48ed6de76e51e3d5f
#   Building wheel for ibm-cos-sdk-core (setup.py): started
#   Building wheel for ibm-cos-sdk-core (setup.py): finished with status 'done'
#   Created wheel for ibm-cos-sdk-core: filename=ibm_cos_sdk_core-2.13.6-py3-none-any.whl size=661477 sha256=4e788c8c7234126729791b971396d647d47ab4912977666855596e55aeef3ba4
#   Stored in directory: c:\users\hardi\appdata\local\pip\cache\wheels\ec\8e\58\e0fdc8135343f394de9c98a48ed20adf698600e01b16ea46bc
#   Building wheel for ibm-cos-sdk-s3transfer (setup.py): started
#   Building wheel for ibm-cos-sdk-s3transfer (setup.py): finished with status 'done'
#   Created wheel for ibm-cos-sdk-s3transfer: filename=ibm_cos_sdk_s3transfer-2.13.6-py3-none-any.whl size=90219 sha256=b051577d927c952a17d80f5074a67ee03896681588cda7daffa78b646473d22b
#   Stored in directory: c:\users\hardi\appdata\local\pip\cache\wheels\52\71\63\176f15a501fd18265938e1c0b2928f9f380b96e3fc15680c80
# Successfully built ibm-cloud-sdk-core ibm-cos-sdk ibm-cos-sdk-core ibm-cos-sdk-s3transfer
# Installing collected packages: urllib3, tabulate, python-dotenv, python_dateutil, lomond, jmespath, requests, load_dotenv, ibm-cos-sdk-core, ibm-cloud-sdk-core, streamlit, ibm-cos-sdk-s3transfer, ibm-cos-sdk, ibm_watson_machine_learning
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.26.14
#     Uninstalling urllib3-1.26.14:
#       Successfully uninstalled urllib3-1.26.14
#   Attempting uninstall: python_dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.2
#     Uninstalling requests-2.28.2:
#       Successfully uninstalled requests-2.28.2
#   Attempting uninstall: streamlit
#     Found existing installation: streamlit 1.22.0
#     Uninstalling streamlit-1.22.0:
#       Successfully uninstalled streamlit-1.22.0
# Successfully installed ibm-cloud-sdk-core-3.16.7 ibm-cos-sdk-2.13.6 ibm-cos-sdk-core-2.13.6 ibm-cos-sdk-s3transfer-2.13.6 ibm_watson_machine_learning-1.0.345 jmespath-1.0.1 load_dotenv-0.1.0 lomond-0.3.3 python-dotenv-1.0.0 python_dateutil-2.9.0.post0 requests-2.32.2 streamlit-1.31.0 tabulate-0.9.0 urllib3-1.26.20
# [notice] A new release of pip is available: 23.3.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Get the token
# Run this cell and enter the token when prompted. For more information, see [documentation](https://cloud.ibm.com/docs/account?topic=account-userapikey&interface=ui#create_user_key)

# %%
from ibm_cloud_sdk_core import IAMTokenManager
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator, BearerTokenAuthenticator
import os, getpass

access_token = IAMTokenManager(
    apikey = getpass.getpass("Please enter your api key (hit enter): "),
    url = "https://iam.cloud.ibm.com/identity/token"
).get_token()
# Out:
# Please enter your api key (hit enter):  ········

# %% [markdown]
# ## Define the inference function
# In this section we define the inference function.
# Invocation parameters can be modified in the following cell

# %%
import requests

class Prompt:
    def __init__(self, access_token, project_id):
        self.access_token = access_token
        self.project_id = project_id

    def generate(self, input, model_id, parameters):
        wml_url = "https://us-south.ml.cloud.ibm.com/ml/v1-beta/generation/text?version=2023-05-28"
        Headers = {
            "Authorization": "Bearer " + self.access_token,
            "Content-Type": "application/json",
            "Accept": "application/json"
        }
        data = {
            "model_id": model_id,
            "input": input,
            "parameters": parameters,
            "project_id": self.project_id
        }
        response = requests.post(wml_url, json=data, headers=Headers)
        if response.status_code == 200:
            return response.json()["results"][0]["generated_text"]
        else:
            return response.text

# %% [markdown]
# ## Define parameters and the prompt for testing
# **Important: provide your project id (look up in the Project Manage tab)**

# %%
# Provide your project id
project_id = "ac252bb7-c5a8-4a4c-910c-9e6f7533c8c2"

model_id = "google/flan-ul2"

parameters = {
    "decoding_method": "greedy",
    "max_new_tokens": 300,
    "min_new_tokens": 50,
    "stop_sequences": ["."],
    "repetition_penalty": 1
}

prompt_input = f"""
Please provide top 5 bullet points in the review provided in '''.\\n\\
nReview:\\n'''I had 2 problems with my experience with my refinance. 1) The appraisal company used only tried to lower 
my house value to fit the comps that he was able to find in the area. My house is unique and he did not use the unique
pictures to compare value. He purposely left them out of the appraisal. 2) I started my loan process on a Thursday. On Saturday 
I tried to contact my loan officer to tell him of the American Express offer that I wanted to apply for.
I was informed that it was too late and I could not use it because it would delay the process. 
I had just received the email about the offer and I had just started the process so how was 
it too late to get in on the $2,000 credit on my current bill. I let it go but I should have dropped 
the process and restarted it because that would have helped me out with my bill.'''\\n\\nTop bullet points:\\n1. 
The appraisal company undervalued the reviewer's house by purposely excluding unique pictures that would have accurately 
ssessed its value.\\n2. The uniqueness of the house was not taken into consideration, and the appraiser relied solely on comps 
that did not reflect its true worth.\\n3. The reviewer attempted to inform their loan officer about an American Express offer they 
wanted to apply for, which would have provided a $2,000 credit on their current bill.\\n4. The loan officer stated it was too late 
to take advantage of the offer as it would delay the process, despite the reviewer having just received the email and recently 
started the loan process.\\n5. The reviewer regrets not dropping the process and restarting it to benefit from the offer,
as it would have helped them with their bill.\\n\\nReview:'''\\nFor the most part my experience was very quick and very easy. 
I did however, have 3 issues.\\n\\n#1 - When I received my final numbers, my costs were over $2000 more than was quoted to 
me over the phone. This was straightened out quickly and matched what I was quoted.\\n\\n#2 - The appraiser had to change 
his schedule and when I didn't know if I could be home for the appraisal, he said he could do it with me not there. 
I do not think this is a wise thing to do or to offer.\\n\\n#3 - When I received my appraisal, it was far lower than 
it should have been. My house appraised for basically the same price I purchased it for 14 years ago. I have kept the 
home up with flooring, paint, etc. It has new shingles on it from last summer, the driveway has been paved, I have about 
three acres landscaped compared to maybe one when I bought it, and have paved the driveway which was originally gravel.\\n\\nEven 
if you discount the insanely high prices that houses are selling for in today's market, the house has increased in value over 
the past fourteen years. In fact, some of the compared properties looked like camps that were not on water, had no basement or
possibly no slab, and very minimal acreage. These comparably priced houses were in no way equal to my 4 bedroom cape, with 
a wraparound deck, on 4 acres, though not on the water, it is overlooking lake around 100 feet away at the most. I feel 
very strongly that the appraisal price was put in at a high enough estimate to satisfy the needs of the refinance loan.'''\\n\\n
Top bullet points:\\n1. Overall, the experience was quick and easy, but there were three specific issues.\\n2. Initially, 
the quoted costs over the phone did not match the final numbers, resulting in a discrepancy of over $2000. However, this 
was promptly resolved.\\n3. The appraiser offered to conduct the appraisal without the homeowner present, which the reviewer 
felt was unwise and not recommended.\\n4. The appraisal value of the house was significantly lower than expected, even considering 
the current high housing market prices. The reviewer mentioned various upgrades and improvements made to the house over the past 
14 years.\\n5. The reviewer expressed a strong belief that the appraisal was deliberately set at a lower value to meet the 
requirements of the refinance loan, despite the property's unique features and advantages compared to the comparables 
used.\\n\\nReview:'''\\nI was told upfront and throughout most of the process that I would be able to get a $25K 
payout/cash back based on the market value of my house that was discussed in the original conversation with the loan officer. 
owever, midway into the process I was told by the loan officer that I was only able to get $17.5K back. Additionally, 
I was told that I would be able to skip 2 months of mortgage payment to help makeup for the cash shortage. However, 
at the end of the day I was told that I could only skip 1 mortgage payment. These 2 drawbacks caused me to not fully satisfy 
the financial reason of why I originally wanted to refinance which was to get the $25K cash.\\n\\nTop bullet points:\\n1. 
The initial agreement with the loan officer stated that the reviewer would receive a $25K cash payout based on the market value 
of their house.\\n2. Midway through the process, the loan officer informed the reviewer that they would only be eligible 
for a $17.5K cash payout, which was lower than initially discussed.\\n3. The reviewer was also promised the ability to
skip two months of mortgage payments to compensate for the cash shortage, but they were later informed that they could
only skip one payment.\\n4. These discrepancies in the cash payout amount and the reduced mortgage payment relief 
prevented the reviewer from fulfilling their original financial objective of obtaining the $25K cash.\\n5. The limitations 
and changes in the terms impacted the overall satisfaction with the refinancing process and compromised the financial benefits 
the reviewer had anticipated.\\n\\nReview:'''\\nI started my loan process toward securing a VA loan. I was waiting for a a
month and a couple weeks, then I was told that the VA needed to acquire my retirement points to verify my veteran status. 
If I knew this is what my loan was on hold for, I could have contacted the VA office right away and got this cleared up. \\nFor whatever reason, 
it took the underwriting department a long time to verify my employment status, even after I uploaded a couple years of my W2
forms from both of my jobs, and they had my Social Security number to further verify my employment status. My loan completion 
date was extended, because I wasn't made aware that they were waiting for my VA status to be approved. The push back for
my mortgage is common for mortgage companies, but this caused my interest rate to go up. Then, the securing of a closing 
lawyer being made aware to me and the lawyer needing three days to get their end prepared for me to go to their office to 
sign the paperwork wasn't made aware to me. My loan missed the second closing date. For whatever reason, the locked in 
interest rate jumped up 5/8 points. After making the banker I was working with aware of this, he didn't understand why 
the locked in interest rate jumped up either. He was nice enough to work on it and was able to get the interest rate 
down in 1/4 of a point, so my mortgage has an interest rate that is 3/8 of a point higher than my locked in interest 
rate in the beginning of this process. Although my interest rate is higher than the locked in interest point, at the end, 
the mortgage is successfully finished.\\n'''\\n\\nTop bullet points:\\n"""

# %% [markdown]
# ## Invoke inference

# %%
prompt = Prompt(access_token, project_id)
prompt.generate(prompt_input, model_id, parameters)
# Out:
# "1. The reviewer was waiting for a a month and a couple weeks to be told that the VA needed to acquire their retirement points to verify their veteran status. 2. It took the underwriting department a long time to verify the reviewer's employment status."

# %% [markdown]
# *Updated by Elena Lowery*
